# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/'My Drive'/'multimodal'/scMM/src
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/multimodal/scMM/src

# %%
# !pip install torchnet pyro-ppl #Other modules are already installed in Colab
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/d5/6c/60e3d9c258d0a145013e7b88d667879ac7ae131c3dd30bb5971548f101bb/pyro_ppl-1.5.1-py3-none-any.whl
# ...

# %%
# !python main.py --experiment 'rna_protein' --model 'rna_protein' --obj 'm_elbo_naive_warmup' --batch_size 32 --epochs 50 --deterministic_warmup 25 --lr 1e-4 --latent_dim 10 --num_hidden_layers 2 --r_hidden_dim 100 --p_hidden_dim 20 --dataset_path '../data/BMNC' --learn_prior
# Out:
# ../experiments/rna_protein/2021-01-25T05:21:13.505149xsav_onr
# Loading  data ...
# Original data contains 15000 cells x 5000 peaks
# Finished loading takes 0.15 min
# Loading  data ...
# Original data contains 15000 cells x 25 peaks
# Finished loading takes 0.03 min
# RNA-seq shape is (15000, 5000)
# CITE-seq shape is (15000, 25)
# Namespace(analytics=True, batch_size=32, cuda=True, dataset_path='../data/BMNC', deterministic_warmup=25, epochs=50, experiment='rna_protein', latent_dim=10, learn_prior=True, llik_scaling=1.0, lr=0.0001, model='rna_protein', no_cuda=False, num_hidden_layers=2, obj='m_elbo_naive_warmup', p_dim=25, p_hidden_dim=20, pre_trained='', print_freq=0, r_dim=5000, r_hidden_dim=100, seed=1)
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:434: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
# ====> Epoch: 001 Train loss: 4241.0072
# ...
