# %%
#import argparse
import datetime
import sys
import json
from collections import defaultdict
from pathlib import Path
from tempfile import mkdtemp

import numpy as np
import torch
import torch.distributions as dist
from torch import optim
from torch.utils.data import DataLoader

import math

import models
#import objectives
import objectives_dev as objectives
from utils import Logger, Timer, save_model, save_vars, unpack_data

from utils import log_mean_exp, is_multidata, kl_divergence, get_mean

from datasets_dev import ATAC_Dataset, RNA_Dataset

import torch
import torch.distributions as dist
import torch.nn as nn
import torch.nn.functional as F
from numpy import prod, sqrt
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import save_image, make_grid

from utils import Constants, get_mean
from vis import plot_embeddings, plot_kls_df, embed_umap

from sklearn.manifold import TSNE
from sklearn.model_selection import ParameterGrid
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors
import pandas as pd

import seaborn as sns
from  scipy.cluster.hierarchy import dendrogram, linkage

# %%
# %matplotlib inline

# %%
#args
experiment = 'paired-seq'
model = 'rna_atac_dev' #VAE試しに使う
obj = 'elbo'
K = 10
looser = False
llik_scaling = 0
batch_size = 256
epochs = 1000
latent_dim = 64
num_hidden_layers = 4
hidden_dim =1024
learn_prior = False
logp = False
print_freq = 0
no_analytics = False
seed = 1

class params():
    
    def __init__(self,
                 experiment,
                 model,
                 obj,
                 K,
                 looser,
                 llik_scaling,
                 batch_size,
                 epochs,
                 latent_dim,
                 num_hidden_layers,
                 hidden_dim,
                 learn_prior,
                 logp,
                 print_freq,
                 no_analytics,
                 seed):
        
        self.experiment = experiment
        self.model = model
        self.obj = obj
        self.K = K
        self.looser = looser
        self.llik_scaling = llik_scaling
        self.batch_size = batch_size
        self.epochs = epochs
        self.latent_dim = latent_dim
        self.num_hidden_layers = num_hidden_layers
        self.hidden_dim = hidden_dim
        self.learn_prior = learn_prior
        self.logp = logp
        self.print_freq = print_freq
        self.no_analytics = no_analytics
        self.seed = seed
        
args = params(experiment,
                model,
                 obj,
                 K,
                 looser,
                 llik_scaling,
                 batch_size,
                 epochs,
                 latent_dim,
                 num_hidden_layers,
                 hidden_dim,
                 learn_prior,
                 logp,
                 print_freq,
                 no_analytics,
                 seed)

# %%
# random seed
# https://pytorch.org/docs/stable/notes/randomness.html
torch.backends.cudnn.benchmark = True
torch.manual_seed(args.seed)
np.random.seed(args.seed)

device = torch.device('cpu')

# load model
modelC = getattr(models, 'VAE_{}'.format(args.model))
model = modelC(args).to(device)

# %%
#Select pretrained model
runId = '2020-04-20T03_55_42.01843728lb_luo'
pretrained_path = '../experiments/' + args.experiment + '/' + runId

print('Loading model {} from {}'.format(model.modelName, pretrained_path))

model.load_state_dict(torch.load(pretrained_path + '/model.rar', map_location=torch.device('cpu') ))
model._pz_params = model._pz_params

runPath = pretrained_path
# Out:
# Loading model rna-atac from ../experiments/paired-seq/2020-04-20T03_55_42.01843728lb_luo

# %%
losses = torch.load(pretrained_path + '/losses.rar', map_location=torch.device('cpu'))
print(losses['train_loss'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-57ba01a63212> in <module>
# ----> 1 losses = torch.load(pretrained_path + '/losses.rar', map_location=torch.device('cpu'))
#       2 print(losses['train_loss'])
#
# ~/proj/multimodal/venv_multimodal/lib/python3.7/site-packages/torch-1.3.1-py3.7-macosx-10.9-x86_64.egg/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     417             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     418         new_fd = True
# --> 419         f = open(f, 'rb')
#     420     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     421         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: '../experiments/paired-seq/2020-04-20T03_55_42.01843728lb_luo/losses.rar'

# %%
model

# %%
#train, test = model.getDataLoaders(batch_size=args.batch_size,device=device)

# %%
#test_size = 1032
#train, val, test = model.getDataLoaders(batch_size=test_size,device=device) #姑息

# %%
train = model.getDataLoaders(batch_size=args.batch_size, device=device) #for train only
# Out:
# Loading  data ...
# Original data contains 41036 cells x 29589 peaks
# Finished loading takes 0.30 min
# Loading  data ...
# Original data contains 41036 cells x 2613805 peaks
# Finished loading takes 1.40 min

# %%
train.dataset[0][1].shape

# %%
#for i,d in enumerate(test): #データ取得
#    if i == 0:
#        data = d

# %%
#MMVAE get data for 5 mini batch
for i, d in enumerate(train):
    if i == 0:
        data0 = d[0]
        data1 = d[1]
    elif i < 5:
        data0 = torch.cat([data0, d[0]], dim=0)
        data1 = torch.cat([data1, d[1]], dim=0)
data = [data0.to(device), data1.to(device)]

# %%
data[0].shape

# %%
#model.reconstruct(data, runPath, epoch=1, sampling=False , N=1)

# %%
#use test data
model.analyse(data, runPath, epoch=1)

# %%
model.histogram(data, runPath)

# %%
qz_xs, px_zs, zss = model(data)

# %%
qz_xs[0]

# %%
x = get_mean(qz_xs[0])[:,0].detach().numpy() 
y = get_mean(qz_xs[0])[:,10].detach().numpy()

# %%
plt.figure()
plt.scatter(x,y)
plt.show()

# %%
for i,d in enumerate(train): #データ取得
    if i == 0:
        data = d

# %%
#model.reconstruct(data, runPath, epoch=1, sampling=False , N=1)

# %%
#full_t, full_s = model.getDataLoaders(batch_size=10309,device=device) #姑息

# %%
#for i,d in enumerate(full_s): #full データ取得
#    if i == 0:
#        full_data = d

# %%
#VAE
for i, d in enumerate(train):
    if i == 0:
        data = d
    else:
        data = torch.cat([data, d], dim=0)

# %%
#MMVAE
for i, d in enumerate(train):
    if i == 0:
        data0 = d[0]
        data1 = d[1]
    else:
        data0 = torch.cat([data0, d[0]], dim=0)
        data1 = torch.cat([data1, d[1]], dim=0)
data = [data0.to(device), data1.to(device)]

# %%
print(data[0].shape[1])
print(data[1].shape[1])

# %%
zero = sum(data[0]==0).detach().numpy()
zero_prop = zero/data[0].shape[0]
print(zero_prop)
print(sum(zero_prop < 0.9))

# %%
#train_rna = pd.DataFrame(data[0].detach().numpy())
#train_rna.to_csv(runPath +'/train_rna.csv')

#train_atac = pd.DataFrame(data[1].detach().numpy())
#train_atac.to_csv(runPath + '/train_atac.csv')

# %%
from scipy.io import mmwrite, mmread
from scipy.sparse import csr_matrix

# %%
train_rna = csr_matrix(data[0].detach().numpy())
train_atac = csr_matrix(data[1].detach().numpy())

# %%
mmwrite(runPath + '/train_rna.mtx', train_rna)
mmwrite(runPath + '/train_atac.mtx', train_atac)

# %%
model.visualize_latent(data, runPath, epoch=1, tsne=True, sampling=False)

# %%
#model.visualize_latent(full_data, runPath, epoch=1, tsne=False, sampling=False)

# %%
#for 2d latent
lats = model.latents(full_data, sampling = False)

# %%
lat_rna = lats[0]
lat_atac = lats[1]

# %%
plt.figure()
plt.scatter(lat_rna[:,0],lat_rna[:,1],s=0.5)
plt.savefig('{}/lat_rna.png'.format(runPath ), dpi=1000)
plt.close('all')

# %%
plt.figure()
plt.scatter(lat_atac[:,0],lat_atac[:,1],s=0.5)
plt.savefig('{}/lat_atac.png'.format(runPath ), dpi=1000)
plt.close('all')

# %%
mean_lats = sum(lats)/len(lats)

# %%
plt.figure()
plt.scatter(mean_lats[:,0],mean_lats[:,1],s=0.5)
plt.savefig('{}/lat_mean.png'.format(runPath ), dpi=1000)
plt.close('all')

# %%
toydata = data[0]
print(toydata)

# %%
link1 = linkage(toydata, 'single')

# %%
link2 = linkage(torch.t(toydata), 'single')

# %%
#print(link1)
print('')
print(link2)

# %%
plt.figure()
den = dendrogram(link1)
plt.show()

# %%
plt.figure()
den = dendrogram(link2)
plt.show()

# %%
train.dataset
len(train.dataset[0][1])

# %%
min(orig)

# %%
x, y = np.vstack((np.random.multivariate_normal([0, 0], [[10.0, 0],[0,20]], 5000) 
                 ,np.random.multivariate_normal([0,15], [[10.0, 0],[0, 5]], 5000))).T

# %%
x

# %%
y

# %%
len(x)

# %%
len(y)

# %%
min(comp)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

#H = ax.hexbin(x,y, gridsize=50, extent=[0, 20, 0, 20], cmap=cm.jet)
H = ax.hexbin(orig, comp, gridsize=50, extent=[-0.1, 1.1, -0.1, 1.1], norm=matplotlib.colors.LogNorm(), cmap=cm.jet)
ax.set_xlabel('original')
ax.set_ylabel('reconstruction')
fig.colorbar(H,ax=ax)
plt.show()

# %%
print(data[0][0][0:100])
print(data[1][0][0:100])
print(sum(data[0][0][0:100]))
print(sum(data[1][0][0:100]))

# %%
train.dataset
